# %% [markdown]
# # Exercise 1
# ## Metro Station Passenger Flow Notebook Setup
# Goal: create a small Spark DataFrame and confirm that the notebook can run Spark correctly.

# %%
print("Spark version:", spark.version)

# %%
metro_data = [
    {"service_date": "2026-04-01", "station_id": "ST001", "station_name": "Oxford Circus",    "line": "Central",   "entries": 24500, "exits": 23800},
    {"service_date": "2026-04-01", "station_id": "ST002", "station_name": "King's Cross",     "line": "Northern",  "entries": 22100, "exits": 21750},
    {"service_date": "2026-04-01", "station_id": "ST003", "station_name": "Waterloo",         "line": "Jubilee",   "entries": 26800, "exits": 26120},
    {"service_date": "2026-04-01", "station_id": "ST004", "station_name": "Victoria",         "line": "Victoria",  "entries": 23250, "exits": 22900},
    {"service_date": "2026-04-01", "station_id": "ST005", "station_name": "Liverpool Street", "line": "Circle",    "entries": 21400, "exits": 20980}
]

# %%
metro_df = spark.createDataFrame(metro_data)
metro_df.printSchema()
display(metro_df)

# %%
print(f"The metro_df has {metro_df.count()} rows")

# %% [markdown]
# 1. What is the notebook used for?
#
# The notebook allows us to run different programs, specially the ones based on spark without that much of a headache. If you one day try to run PySpark locally on your machine, some of the features can be really tricky.
#
# 2. What is compute used for?
#
# Compute is the processing power attached to your workspace or account. For instances, right now even if you run a print in a cell it takes more than what it would take in your laptop, because we are using a free account and this processing part is done somewhere else. If we decided to go to the premium mode and pay money here, we can increase the compute power and run things faster.
#
# 3. What does the Spark DataFrame represent in this exercise?
#
# Is a representation of the data we loaded from the list you provided us. This dataframe is the basic tool for spark running efficiently the whole data before possible transformations.
#
# 4. What did display() help you see?
#
# Display shows a bit of the dataframe. There we can see the columns and the rows disposition of the data we have
#
# 5. What did count() confirm?
#
# Count allows us to see the whole amount of lines the dataframe has. Is an action and it's considered costly.
